# %%
# Load libraries
import pandas as pd
from sklearn.ensemble import RandomForestClassifier # Import RandomForest Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
#make sure you have your labels correct
#some files have this in the file - others it is in the description
#if it is in the file you can copy them here then delete that line in the file
col_names = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness', 'insulin',
'bmi', 'diabetes_pedigree_function', 'age', 'outcome']
# load dataset
data = pd.read_csv("diabetes.csv", header=None, names=col_names)
#take a peek to see if this looks right
data.head()
# Out:
#    pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 0            6      148              72              35        0  33.6
# 1            1       85              66              29        0  26.6
# 2            8      183              64               0        0  23.3
# 3            1       89              66              23       94  28.1
# 4            0      137              40              35      168  43.1
#
#    diabetes_pedigree_function  age  outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1

# %%
#split dataset in features and target variable
feature_cols = ['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness', 'insulin',
'bmi', 'diabetes_pedigree_function', 'age']
X = data[feature_cols] # Features
y = data['outcome'] # Target variable
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
# 70% training and 30% test

# %%
forest = RandomForestClassifier()
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy of testing:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy of testing: 0.8138528138528138
# Random forest train / test accuracies: 1.0 / 0.8138528138528138

# %%
forest = RandomForestClassifier(criterion='entropy')
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy of testing:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy of testing: 0.8051948051948052
# Random forest train / test accuracies: 1.0 / 0.8051948051948052

# %%
forest = RandomForestClassifier(criterion='log_loss')
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy of testing:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy of testing: 0.7922077922077922
# Random forest train / test accuracies: 1.0 / 0.7922077922077922

# %% [markdown]
# # Answers to Questions pg 2
# <p>1. There isn't too much of a difference between the different types of criterion. It depends on how many times you run it, most get in the range of 79-80% test accuracy with the one current outlier with the first gini run. I don't think this is significant, since they all give similar percentages. </p>
# <p>2. The accuracy of this random forest does a little better than 10% than just using one tree that is overfit. However, when we limited the depth of the tree to only a few layers, the accuracy there was ~78% which is 2-3% less than what is gotten above with the random forest. Overall, the random forest is slightly better than having only one tree. </p>

# %%
forest = RandomForestClassifier(n_estimators=200, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7965367965367965
# Random forest train / test accuracies: 1.0 / 0.7965367965367965

# %%
forest = RandomForestClassifier(n_estimators=150, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7965367965367965
# Random forest train / test accuracies: 1.0 / 0.7965367965367965

# %%
forest = RandomForestClassifier(n_estimators=90, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 1.0 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=75, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7878787878787878
# Random forest train / test accuracies: 1.0 / 0.7878787878787878

# %%
forest = RandomForestClassifier(n_estimators=50, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.9962756052141527 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=25, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7965367965367965
# Random forest train / test accuracies: 0.9962756052141527 / 0.7965367965367965

# %%
forest = RandomForestClassifier(n_estimators=10, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.9832402234636871 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=5, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7748917748917749
# Random forest train / test accuracies: 0.9590316573556797 / 0.7748917748917749

# %% [markdown]
# # Answers to Question pg 3
# <p>1. To me, it seems like the more trees there are, the better the results are. There was an outlier with 25 trees that had the same testing precision as 100-200 trees did; however, the fewer the amount of trees, the training accuracy starts lowering. I think that the more trees you have, the better/more general the results will become. As the forest becomes larger, the more of a consensus has to occur to get the same vote, which also means that outliers shouldn't happen as often. </p>

# %%
#using a random forest to view
forest = RandomForestClassifier(n_estimators=50, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)

#can see any of the estimators you made
estimator = forest.estimators_[10]#extract a single tree
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(estimator, out_file=dot_data,
filled=True, rounded=True,
special_characters=True, feature_names =
feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('diabetesEnsembleTree10.png')
Image(graph.create_png())

# %%
#20 trees without max depth
forest = RandomForestClassifier(n_estimators=20, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.994413407821229 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=20,max_depth=7, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7965367965367965
# Random forest train / test accuracies: 0.9068901303538175 / 0.7965367965367965

# %%
forest = RandomForestClassifier(n_estimators=20,max_depth=5, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.8361266294227188 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=20,max_depth=4, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.819366852886406 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=20,max_depth=3, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7662337662337663
# Random forest train / test accuracies: 0.7746741154562383 / 0.7662337662337663

# %%
forest = RandomForestClassifier(n_estimators=20,max_depth=2, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7575757575757576
# Random forest train / test accuracies: 0.7560521415270018 / 0.7575757575757576

# %%
forest = RandomForestClassifier(n_estimators=20,max_depth=1, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7142857142857143
# Random forest train / test accuracies: 0.7132216014897579 / 0.7142857142857143

# %%
forest = RandomForestClassifier(n_estimators=100,max_depth=4, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7792207792207793
# Random forest train / test accuracies: 0.8212290502793296 / 0.7792207792207793

# %%
forest = RandomForestClassifier(n_estimators=150,max_depth=4, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.8230912476722533 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=200,max_depth=4, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7922077922077922
# Random forest train / test accuracies: 0.8268156424581006 / 0.7922077922077922

# %%
forest = RandomForestClassifier(n_estimators=1,max_depth=4, random_state=1)#Play with the depth
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.7705627705627706
# Random forest train / test accuracies: 0.7672253258845437 / 0.7705627705627706

# %% [markdown]
# # Answers to Questions pg 4
# <p>1. Compared to the other trees, the ones with a fixed depth have a closer train to test accuracy. If anything, the other forests could be seen as overfitting much more than the forest with a fixed depth, but the overall test accuracy is slightly lower for some of the forests in comparison to their counterparts with the same number of trees. It makes sense that the fewer the number of trees in a forest with a generalized tree structure (low depth) the better the accuracy of the tree is simply due to how we maximized one tree for the data. Yet it does partially surprise me that the results are so close, the only answer I have is that possibly the trees are more general, the more the overall forest will be general since a certain number of trees could act like one tree in a way once it gets to a certain number n. </p>
# <p>2. It seemed to me that the max depth worked the best with 4 overall and 20 or over 100 classifiers. Both seemed to not have too much overfit whilst maintaing around the 79% mark for test accuracy. However all of the train accuracy is quite bad in comparison to the forests of overfit trees. </p>

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=None)#default learn rate is 1
ada = AdaBoostClassifier(estimator=tree, random_state=1)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.6926406926406926
# AdaBoost train / test accuracies: 1.0 / 0.6926406926406926

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion="entropy", random_state=1,max_depth=None)#defaultlearn rate is 1
ada = AdaBoostClassifier(estimator=tree, random_state=1)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7012987012987013
# AdaBoost train / test accuracies: 1.0 / 0.7012987012987013

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion="log_loss", random_state=1,max_depth=None)#defaultlearn rate is 1
ada = AdaBoostClassifier(estimator=tree, random_state=1)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7012987012987013
# AdaBoost train / test accuracies: 1.0 / 0.7012987012987013

# %% [markdown]
# # Answers to Question pg 5
# <p>1. It seems to have a tiny bit of impact depending on which criteria used. It seems to me that log_loss and entropy are simliar(or the same maybe just different terminology) and that gini indexing does a little bit worse in this scenario by a whole percent in the testing accuracy. </p>

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=3)
ada = AdaBoostClassifier(estimator=tree, random_state=1)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7359307359307359
# AdaBoost train / test accuracies: 1.0 / 0.7359307359307359

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7835497835497836
# AdaBoost train / test accuracies: 0.8230912476722533 / 0.7835497835497836

# %% [markdown]
# # Answers to Question Set 1 pg 6
# <p>1. Having a lower depth helps the accuracy of the adaboost classifier by quite a large percentage. Boosting relies on multiple small trees that are all weighted differently. With larger trees instead of just stumps, the model will have tree that are all weighted differently which may not necessarily lead to a great result since we are basically creating a forest that is unfairly weighted. This also means that the more overfit the tree (since the weight will be given in favor of trees that classify better), the more weight it is given and making the boost model more overfit in general. </p>

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=200)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.8051948051948052
# AdaBoost train / test accuracies: 0.8938547486033519 / 0.8051948051948052

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=20)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7705627705627706
# AdaBoost train / test accuracies: 0.8007448789571695 / 0.7705627705627706

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=400)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7662337662337663
# AdaBoost train / test accuracies: 0.9348230912476723 / 0.7662337662337663

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=1000)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.7489177489177489
# AdaBoost train / test accuracies: 0.9906890130353817 / 0.7489177489177489

# %% [markdown]
# # Answers to Question Set 2 pg 6
# <p>1. It seems like having too few estimators affects the data in the way of underfitting, having a rough training and testing set. Whereas having a set of too many estimators tends to overfit - leading to good training accuracy and dipping testing accuracy. Somewhere in the middle is a good spot to be, and it seems could be roughly around 80% accuracy in the range of 100 to less than 200 estimators. For the small number of estimators, this could be due there being only a small number of classifications happening, and majority vote could easily be entirely wrong, and the opposite goes for the large number of estimators. They have too many different classifications happenning which are all tailored to the training data set which leads to the overfitting. </p>

# %% [markdown]
# # Forest / Boosting with own dataset

# %%
# Load libraries
import pandas as pd
from sklearn.ensemble import RandomForestClassifier # Import RandomForest Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
#make sure you have your labels correct
#some files have this in the file - others it is in the description
col_names = ['ACCESS_ALL_DOWNLOADS','ACCESS_CACHE_FILESYSTEM','ACCESS_CHECKIN_PROPERTIES',
                'ACCESS_COARSE_LOCATION','ACCESS_COARSE_UPDATES','ACCESS_FINE_LOCATION',
                'ACCESS_LOCATION_EXTRA_COMMANDS','ACCESS_MOCK_LOCATION','ACCESS_MTK_MMHW',
                'ACCESS_NETWORK_STATE','ACCESS_PROVIDER','ACCESS_SERVICE','ACCESS_SHARED_DATA',
                'ACCESS_SUPERUSER','ACCESS_SURFACE_FLINGER','ACCESS_WIFI_STATE','activityCalled',
                'ACTIVITY_RECOGNITION','ACCOUNT_MANAGER','ADD_VOICEMAIL','ANT','ANT_ADMIN',
                'AUTHENTICATE_ACCOUNTS','AUTORUN_MANAGER_LICENSE_MANAGER','AUTORUN_MANAGER_LICENSE_SERVICE(.autorun)',
                'BATTERY_STATS','BILLING','BIND_ACCESSIBILITY_SERVICE','BIND_APPWIDGET',
                'BIND_CARRIER_MESSAGING_SERVICE','BIND_DEVICE_ADMIN','BIND_DREAM_SERVICE',
                'BIND_GET_INSTALL_REFERRER_SERVICE','BIND_INPUT_METHOD','BIND_NFC_SERVICE',
                'BIND_goodwareTIFICATION_LISTENER_SERVICE','BIND_PRINT_SERVICE','BIND_REMOTEVIEWS',
                'BIND_TEXT_SERVICE','BIND_TV_INPUT','BIND_VOICE_INTERACTION','BIND_VPN_SERVICE',
                'BIND_WALLPAPER','BLUETOOTH','BLUETOOTH_ADMIN','BLUETOOTH_PRIVILEGED','BODY_SENSORS',
                'BRICK','BROADCAST_PACKAGE_REMOVED','BROADCAST_SMS','BROADCAST_STICKY','BROADCAST_WAP_PUSH',
                'C2D_MESSAGE','CALL_PHONE','CALL_PRIVILEGED','CAMERA','CAPTURE_AUDIO_OUTPUT',
                'CAPTURE_SECURE_VIDEO_OUTPUT','CAPTURE_VIDEO_OUTPUT','CHANGE_COMPONENT_ENABLED_STATE',
                'CHANGE_CONFIGURATION','CHANGE_DISPLAY_MODE','CHANGE_NETWORK_STATE',
                'CHANGE_WIFI_MULTICAST_STATE','CHANGE_WIFI_STATE','CHECK_LICENSE','CLEAR_APP_CACHE',
                'CLEAR_APP_USER_DATA','CONTROL_LOCATION_UPDATES','DATABASE_INTERFACE_SERVICE',
                'DELETE_CACHE_FILES','DELETE_PACKAGES','DEVICE_POWER','DIAGgoodwareSTIC','DISABLE_KEYGUARD',
                'DOWNLOAD_SERVICE','DOWNLOAD_WITHOUT_goodwareTIFICATION','DUMP','EXPAND_STATUS_BAR',
                'EXTENSION_PERMISSION','FACTORY_TEST','FLASHLIGHT','FORCE_BACK','FULLSCREEN.FULL',
                'GET_ACCOUNTS','GET_PACKAGE_SIZE','GET_TASKS','GET_TOP_ACTIVITY_INFO','GLOBAL_SEARCH',
                'GOOGLE_AUTH','GOOGLE_PHOTOS','HARDWARE_TEST','INJECT_EVENTS','INSTALL_LOCATION_PROVIDER',
                'INSTALL_PACKAGES','INSTALL_SHORTCUT','INTERACT_ACROSS_USERS','INTERNAL_SYSTEM_WINDOW',
                'INTERNET','JPUSH_MESSAGE','KILL_BACKGROUND_PROCESSES','LOCATION_HARDWARE','MANAGE_ACCOUNTS',
                'MANAGE_APP_TOKENS','MANAGE_DOCUMENTS','MAPS_RECEIVE','MASTER_CLEAR','MEDIA_BUTTON',
                'MEDIA_CONTENT_CONTROL','MESSAGE','MODIFY_AUDIO_SETTINGS','MODIFY_PHONE_STATE',
                'MOUNT_FORMAT_FILESYSTEMS','MOUNT_UNMOUNT_FILESYSTEMS','NFC','PERSISTENT_ACTIVITY',
                'PERMISSION','PERMISSION_RUN_TASKS','PLUGIN','PROCESS_OUTGOING_CALLS','READ',
                'READ_ATTACHMENT','READ_AVESTTINGS','READ_CALENDAR','READ_CALL_LOG','READ_CONTACTS',
                'READ_CONTENT_PROVIDER','READ_DATA','READ_DATABASES','READ_EXTERNAL_STORAGE',
                'READ_FRAME_BUFFER','READ_GMAIL','READ_GSERVICES','READ_HISTORY_BOOKMARKS',
                'READ_INPUT_STATE','READ_LOGS','READ_MESSAGES','READ_OWNER_DATA','READ_PHONE_STATE',
                'READ_PROFILE','READ_SETTINGS','READ_SMS','READ_SOCIAL_STREAM','READ_SYNC_SETTINGS',
                'READ_SYNC_STATS','READ_USER_DICTIONARY','READ_VOICEMAIL','REBOOT','RECEIVE',
                'RECEIVE_BOOT_COMPLETED','RECEIVE_MMS','RECEIVE_SIGNED_DATA_RESULT','RECEIVE_SMS',
                'RECEIVE_USER_PRESENT','RECEIVE_WAP_PUSH','RECORD_AUDIO','REORDER_TASKS','RESPOND',
                'RESTART_PACKAGES','REQUEST','SDCARD_WRITE','SEND','SEND_RESPOND_VIA_MESSAGE','SEND_SMS',
                'SET_ACTIVITY_WATCHER','SET_ALARM','SET_ALWAYS_FINISH','SET_ANIMATION_SCALE','SET_DEBUG_APP',
                'SET_ORIENTATION','SET_POINTER_SPEED','SET_PREFERRED_APPLICATIONS','SET_PROCESS_LIMIT',
                'SET_TIME','SET_TIME_ZONE','SET_WALLPAPER','SET_WALLPAPER_HINTS',
                'SIGNAL_PERSISTENT_PROCESSES','STATUS_BAR','STORAGE','SUBSCRIBED_FEEDS_READ',
                'SUBSCRIBED_FEEDS_WRITE','SYSTEM_ALERT_WINDOW','TRANSMIT_IR','UNINSTALL_SHORTCUT',
                'UPDATE_DEVICE_STATS','USES_POLICY_FORCE_LOCK','USE_CREDENTIALS','USE_FINGERPRINT',
                'USE_SIP','VIBRATE','WAKE_LOCK','WRITE','WRITE_APN_SETTINGS','WRITE_AVSETTING',
                'WRITE_CALENDAR','WRITE_CALL_LOG','WRITE_CONTACTS','WRITE_DATA','WRITE_DATABASES',
                'WRITE_EXTERNAL_STORAGE','WRITE_GSERVICES','WRITE_HISTORY_BOOKMARKS',
                'WRITE_INTERNAL_STORAGE','WRITE_MEDIA_STORAGE','WRITE_OWNER_DATA','WRITE_PROFILE',
                'WRITE_SECURE_SETTINGS','WRITE_SETTINGS','WRITE_SMS','WRITE_SOCIAL_STREAM',
                'WRITE_SYNC_SETTINGS','WRITE_USER_DICTIONARY','WRITE_VOICEMAIL',
                'Ljava/lang/reflect/Method;->invoke','Ljavax/crypto/Cipher;->doFinal',
                'Ljava/lang/Runtime;->exec','Ljava/lang/System;->load',
                'Ldalvik/system/DexClassLoader;->loadClass','Ljava/lang/System;->loadLibrary',
                'Ljava/net/URL;->openConnection','Landroid/hardware/Camera;->open',
                'Landroid/hardware/Camera;->takePicture',
                'Landroid/telephony/SmsManager;->sendMultipartTextMessage',
                'Landroid/telephony/SmsManager;->sendTextMessage',
                'Landroid/media/AudioRecord;->startRecording',
                'Landroid/telephony/TelephonyManager;->getCellLocation',
                'Lcom/google/android/gms/location/LocationClient;->getLastLocation',
                'Landroid/location/LocationManager;->getLastKgoodwarewnLocation',
                'Landroid/telephony/TelephonyManager;->getDeviceId',
                'Landroid/content/pm/PackageManager;->getInstalledApplications',
                'Landroid/content/pm/PackageManager;->getInstalledPackages',
                'Landroid/telephony/TelephonyManager;->getLine1Number',
                'Landroid/telephony/TelephonyManager;->getNetworkOperator',
                'Landroid/telephony/TelephonyManager;->getNetworkOperatorName',
                'Landroid/telephony/TelephonyManager;->getNetworkCountryIso',
                'Landroid/telephony/TelephonyManager;->getSimOperator',
                'Landroid/telephony/TelephonyManager;->getSimOperatorName',
                'Landroid/telephony/TelephonyManager;->getSimCountryIso',
                'Landroid/telephony/TelephonyManager;->getSimSerialNumber',
                'Lorg/apache/http/impl/client/DefaultHttpClient;->execute',
                'Label']
# load dataset
data = pd.read_csv("TUANDROMD.csv", header=None, names=col_names, low_memory=False)
#take a peek to see if this looks right
data.head()
# Out:
#    ACCESS_ALL_DOWNLOADS  ACCESS_CACHE_FILESYSTEM  ACCESS_CHECKIN_PROPERTIES  \
# 0                     0                        0                          0
# 1                     0                        0                          0
# 2                     0                        0                          0
# 3                     0                        0                          0
# 4                     0                        0                          0
#
#    ACCESS_COARSE_LOCATION  ACCESS_COARSE_UPDATES  ACCESS_FINE_LOCATION  \
# 0                       0                      0                     0
# 1                       0                      0                     0
# 2                       0                      0                     0
# 3                       0                      0                     0
# 4                       0                      0                     0
#
#    ACCESS_LOCATION_EXTRA_COMMANDS  ACCESS_MOCK_LOCATION  ACCESS_MTK_MMHW  \
# ...

# %%
#split dataset in features and target variable
feature_cols = ['ACCESS_ALL_DOWNLOADS','ACCESS_CACHE_FILESYSTEM','ACCESS_CHECKIN_PROPERTIES',
                'ACCESS_COARSE_LOCATION','ACCESS_COARSE_UPDATES','ACCESS_FINE_LOCATION',
                'ACCESS_LOCATION_EXTRA_COMMANDS','ACCESS_MOCK_LOCATION','ACCESS_MTK_MMHW',
                'ACCESS_NETWORK_STATE','ACCESS_PROVIDER','ACCESS_SERVICE','ACCESS_SHARED_DATA',
                'ACCESS_SUPERUSER','ACCESS_SURFACE_FLINGER','ACCESS_WIFI_STATE','activityCalled',
                'ACTIVITY_RECOGNITION','ACCOUNT_MANAGER','ADD_VOICEMAIL','ANT','ANT_ADMIN',
                'AUTHENTICATE_ACCOUNTS','AUTORUN_MANAGER_LICENSE_MANAGER','AUTORUN_MANAGER_LICENSE_SERVICE(.autorun)',
                'BATTERY_STATS','BILLING','BIND_ACCESSIBILITY_SERVICE','BIND_APPWIDGET',
                'BIND_CARRIER_MESSAGING_SERVICE','BIND_DEVICE_ADMIN','BIND_DREAM_SERVICE',
                'BIND_GET_INSTALL_REFERRER_SERVICE','BIND_INPUT_METHOD','BIND_NFC_SERVICE',
                'BIND_goodwareTIFICATION_LISTENER_SERVICE','BIND_PRINT_SERVICE','BIND_REMOTEVIEWS',
                'BIND_TEXT_SERVICE','BIND_TV_INPUT','BIND_VOICE_INTERACTION','BIND_VPN_SERVICE',
                'BIND_WALLPAPER','BLUETOOTH','BLUETOOTH_ADMIN','BLUETOOTH_PRIVILEGED','BODY_SENSORS',
                'BRICK','BROADCAST_PACKAGE_REMOVED','BROADCAST_SMS','BROADCAST_STICKY','BROADCAST_WAP_PUSH',
                'C2D_MESSAGE','CALL_PHONE','CALL_PRIVILEGED','CAMERA','CAPTURE_AUDIO_OUTPUT',
                'CAPTURE_SECURE_VIDEO_OUTPUT','CAPTURE_VIDEO_OUTPUT','CHANGE_COMPONENT_ENABLED_STATE',
                'CHANGE_CONFIGURATION','CHANGE_DISPLAY_MODE','CHANGE_NETWORK_STATE',
                'CHANGE_WIFI_MULTICAST_STATE','CHANGE_WIFI_STATE','CHECK_LICENSE','CLEAR_APP_CACHE',
                'CLEAR_APP_USER_DATA','CONTROL_LOCATION_UPDATES','DATABASE_INTERFACE_SERVICE',
                'DELETE_CACHE_FILES','DELETE_PACKAGES','DEVICE_POWER','DIAGgoodwareSTIC','DISABLE_KEYGUARD',
                'DOWNLOAD_SERVICE','DOWNLOAD_WITHOUT_goodwareTIFICATION','DUMP','EXPAND_STATUS_BAR',
                'EXTENSION_PERMISSION','FACTORY_TEST','FLASHLIGHT','FORCE_BACK','FULLSCREEN.FULL',
                'GET_ACCOUNTS','GET_PACKAGE_SIZE','GET_TASKS','GET_TOP_ACTIVITY_INFO','GLOBAL_SEARCH',
                'GOOGLE_AUTH','GOOGLE_PHOTOS','HARDWARE_TEST','INJECT_EVENTS','INSTALL_LOCATION_PROVIDER',
                'INSTALL_PACKAGES','INSTALL_SHORTCUT','INTERACT_ACROSS_USERS','INTERNAL_SYSTEM_WINDOW',
                'INTERNET','JPUSH_MESSAGE','KILL_BACKGROUND_PROCESSES','LOCATION_HARDWARE','MANAGE_ACCOUNTS',
                'MANAGE_APP_TOKENS','MANAGE_DOCUMENTS','MAPS_RECEIVE','MASTER_CLEAR','MEDIA_BUTTON',
                'MEDIA_CONTENT_CONTROL','MESSAGE','MODIFY_AUDIO_SETTINGS','MODIFY_PHONE_STATE',
                'MOUNT_FORMAT_FILESYSTEMS','MOUNT_UNMOUNT_FILESYSTEMS','NFC','PERSISTENT_ACTIVITY',
                'PERMISSION','PERMISSION_RUN_TASKS','PLUGIN','PROCESS_OUTGOING_CALLS','READ',
                'READ_ATTACHMENT','READ_AVESTTINGS','READ_CALENDAR','READ_CALL_LOG','READ_CONTACTS',
                'READ_CONTENT_PROVIDER','READ_DATA','READ_DATABASES','READ_EXTERNAL_STORAGE',
                'READ_FRAME_BUFFER','READ_GMAIL','READ_GSERVICES','READ_HISTORY_BOOKMARKS',
                'READ_INPUT_STATE','READ_LOGS','READ_MESSAGES','READ_OWNER_DATA','READ_PHONE_STATE',
                'READ_PROFILE','READ_SETTINGS','READ_SMS','READ_SOCIAL_STREAM','READ_SYNC_SETTINGS',
                'READ_SYNC_STATS','READ_USER_DICTIONARY','READ_VOICEMAIL','REBOOT','RECEIVE',
                'RECEIVE_BOOT_COMPLETED','RECEIVE_MMS','RECEIVE_SIGNED_DATA_RESULT','RECEIVE_SMS',
                'RECEIVE_USER_PRESENT','RECEIVE_WAP_PUSH','RECORD_AUDIO','REORDER_TASKS','RESPOND',
                'RESTART_PACKAGES','REQUEST','SDCARD_WRITE','SEND','SEND_RESPOND_VIA_MESSAGE','SEND_SMS',
                'SET_ACTIVITY_WATCHER','SET_ALARM','SET_ALWAYS_FINISH','SET_ANIMATION_SCALE','SET_DEBUG_APP',
                'SET_ORIENTATION','SET_POINTER_SPEED','SET_PREFERRED_APPLICATIONS','SET_PROCESS_LIMIT',
                'SET_TIME','SET_TIME_ZONE','SET_WALLPAPER','SET_WALLPAPER_HINTS',
                'SIGNAL_PERSISTENT_PROCESSES','STATUS_BAR','STORAGE','SUBSCRIBED_FEEDS_READ',
                'SUBSCRIBED_FEEDS_WRITE','SYSTEM_ALERT_WINDOW','TRANSMIT_IR','UNINSTALL_SHORTCUT',
                'UPDATE_DEVICE_STATS','USES_POLICY_FORCE_LOCK','USE_CREDENTIALS','USE_FINGERPRINT',
                'USE_SIP','VIBRATE','WAKE_LOCK','WRITE','WRITE_APN_SETTINGS','WRITE_AVSETTING',
                'WRITE_CALENDAR','WRITE_CALL_LOG','WRITE_CONTACTS','WRITE_DATA','WRITE_DATABASES',
                'WRITE_EXTERNAL_STORAGE','WRITE_GSERVICES','WRITE_HISTORY_BOOKMARKS',
                'WRITE_INTERNAL_STORAGE','WRITE_MEDIA_STORAGE','WRITE_OWNER_DATA','WRITE_PROFILE',
                'WRITE_SECURE_SETTINGS','WRITE_SETTINGS','WRITE_SMS','WRITE_SOCIAL_STREAM',
                'WRITE_SYNC_SETTINGS','WRITE_USER_DICTIONARY','WRITE_VOICEMAIL',
                'Ljava/lang/reflect/Method;->invoke','Ljavax/crypto/Cipher;->doFinal',
                'Ljava/lang/Runtime;->exec','Ljava/lang/System;->load',
                'Ldalvik/system/DexClassLoader;->loadClass','Ljava/lang/System;->loadLibrary',
                'Ljava/net/URL;->openConnection','Landroid/hardware/Camera;->open',
                'Landroid/hardware/Camera;->takePicture',
                'Landroid/telephony/SmsManager;->sendMultipartTextMessage',
                'Landroid/telephony/SmsManager;->sendTextMessage',
                'Landroid/media/AudioRecord;->startRecording',
                'Landroid/telephony/TelephonyManager;->getCellLocation',
                'Lcom/google/android/gms/location/LocationClient;->getLastLocation',
                'Landroid/location/LocationManager;->getLastKgoodwarewnLocation',
                'Landroid/telephony/TelephonyManager;->getDeviceId',
                'Landroid/content/pm/PackageManager;->getInstalledApplications',
                'Landroid/content/pm/PackageManager;->getInstalledPackages',
                'Landroid/telephony/TelephonyManager;->getLine1Number',
                'Landroid/telephony/TelephonyManager;->getNetworkOperator',
                'Landroid/telephony/TelephonyManager;->getNetworkOperatorName',
                'Landroid/telephony/TelephonyManager;->getNetworkCountryIso',
                'Landroid/telephony/TelephonyManager;->getSimOperator',
                'Landroid/telephony/TelephonyManager;->getSimOperatorName',
                'Landroid/telephony/TelephonyManager;->getSimCountryIso',
                'Landroid/telephony/TelephonyManager;->getSimSerialNumber',
                'Lorg/apache/http/impl/client/DefaultHttpClient;->execute']

X = data[feature_cols] # Features
y = data.Label # Target variable - notice - you need to spell the column name for the target correctly for this to work
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
# 70% training and 30% test

# %% [markdown]
# ## Forest Testing

# %%
forest = RandomForestClassifier(criterion='entropy', n_estimators=100, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9925373134328358
# Random forest train / test accuracies: 0.9977592829705506 / 0.9925373134328358

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=100, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.994776119402985
# Random forest train / test accuracies: 0.9977592829705506 / 0.994776119402985

# %% [markdown]
# #### Note: Gini seems to have better accuracy, so continue testing with gini

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=5, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.991044776119403
# Random forest train / test accuracies: 0.9971190781049936 / 0.991044776119403

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=10, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9925373134328358
# Random forest train / test accuracies: 0.9971190781049936 / 0.9925373134328358

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=20, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9940298507462687
# Random forest train / test accuracies: 0.9977592829705506 / 0.9940298507462687

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=40, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9955223880597015
# Random forest train / test accuracies: 0.9977592829705506 / 0.9955223880597015

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9955223880597015
# Random forest train / test accuracies: 0.9977592829705506 / 0.9955223880597015

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=75, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9940298507462687
# Random forest train / test accuracies: 0.9977592829705506 / 0.9940298507462687

# %% [markdown]
# #### Note: Seems best around 40 - 50 estimators

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=5, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9679104477611941
# Random forest train / test accuracies: 0.9804737516005122 / 0.9679104477611941

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=10, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9850746268656716
# Random forest train / test accuracies: 0.9923175416133163 / 0.9850746268656716

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=12, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9865671641791045
# Random forest train / test accuracies: 0.9942381562099872 / 0.9865671641791045

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=15, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9940298507462687
# Random forest train / test accuracies: 0.9977592829705506 / 0.9940298507462687

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=18, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9940298507462687
# Random forest train / test accuracies: 0.9977592829705506 / 0.9940298507462687

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=20, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.994776119402985
# Random forest train / test accuracies: 0.9977592829705506 / 0.994776119402985

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, max_depth=25, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9940298507462687
# Random forest train / test accuracies: 0.9977592829705506 / 0.9940298507462687

# %%
#NO MAX DEPTH -> FOR COMPARISON
forest = RandomForestClassifier(criterion='gini', n_estimators=50, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9955223880597015
# Random forest train / test accuracies: 0.9977592829705506 / 0.9955223880597015

# %% [markdown]
# #### Note: Setting a max_depth makes the results worse overall with this forest

# %% [markdown]
# ## BEST FOREST FOR DATA
# ##### Max Depth: no limit
# ##### Number of Trees: 40-50
# ##### Tree classification method: Gini

# %%
forest = RandomForestClassifier(criterion='gini', n_estimators=50, random_state=1)#Play with the number of estimators
forest.fit(X_train, y_train)
y_test_pred=forest.predict(X_test)
y_train_pred=forest.predict(X_train)
forest_train = metrics.accuracy_score(y_train, y_train_pred)
forest_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"Random forest train / test accuracies: {forest_train} / {forest_test}")
# Out:
# Accuracy: 0.9955223880597015
# Random forest train / test accuracies: 0.9977592829705506 / 0.9955223880597015

# %% [markdown]
# # Boosting

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='gini', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=100)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9805970149253731
# AdaBoost train / test accuracies: 0.9881562099871959 / 0.9805970149253731

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=100)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9813432835820896
# AdaBoost train / test accuracies: 0.9881562099871959 / 0.9813432835820896

# %% [markdown]
# #### Note: Entropy might do a little better than gini with boosting. With a few different num estmators, they were both fairly similar

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=10)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9589552238805971
# AdaBoost train / test accuracies: 0.9683098591549296 / 0.9589552238805971

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=30)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9723880597014926
# AdaBoost train / test accuracies: 0.9839948783610756 / 0.9723880597014926

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=60)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9791044776119403
# AdaBoost train / test accuracies: 0.9868758002560819 / 0.9791044776119403

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=90)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9791044776119403
# AdaBoost train / test accuracies: 0.9884763124199744 / 0.9791044776119403

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=100)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9813432835820896
# AdaBoost train / test accuracies: 0.9881562099871959 / 0.9813432835820896

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=110)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9813432835820896
# AdaBoost train / test accuracies: 0.9894366197183099 / 0.9813432835820896

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=120)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9813432835820896
# AdaBoost train / test accuracies: 0.9894366197183099 / 0.9813432835820896

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=135)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9805970149253731
# AdaBoost train / test accuracies: 0.9897567221510883 / 0.9805970149253731

# %% [markdown]
# #### Note: does best with 110-120 estimators

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=1)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=115)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9813432835820896
# AdaBoost train / test accuracies: 0.9894366197183099 / 0.9813432835820896

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=2)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=115)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9895522388059701
# AdaBoost train / test accuracies: 0.9977592829705506 / 0.9895522388059701

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=3)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=115)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9932835820895523
# AdaBoost train / test accuracies: 0.9977592829705506 / 0.9932835820895523

# %%
#Boosting
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
tree = DecisionTreeClassifier(criterion='entropy', random_state=1,max_depth=4)
ada = AdaBoostClassifier(estimator=tree, random_state=1, n_estimators=115)
adaModel = ada.fit(X_train, y_train)
y_test_pred=adaModel.predict(X_test)
y_train_pred=adaModel.predict(X_train)
adaModel_train = metrics.accuracy_score(y_train, y_train_pred)
adaModel_test = metrics.accuracy_score(y_test, y_test_pred)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_test_pred))
print(f"AdaBoost train / test accuracies: {adaModel_train} / {adaModel_test}")
# Out:
# Accuracy: 0.9895522388059701
# AdaBoost train / test accuracies: 0.9977592829705506 / 0.9895522388059701

# %% [markdown]
# #### Note: Does best with max depth of 3

# %% [markdown]
# ## BEST BOOST SETTINGS FOR DATA
# ##### Max Depth: 3
# ##### Number of Trees: 110-120
# ##### Tree classification method: Entropy

# %% [markdown]
# # Answers to Question Set 3 pg 6
# <p>1. For the forests, they were similar in a some ways, but overall number difference was the main difference. The data I had did better with more classifiers then the diabetes data, but the method and the max depth had the same sort of effect on the forest. With boosting, there also were a few differences. The way in which the number of trees/stumps had a sweet spot stayed the same and the amount of trees/stumps for that was quite similar. However, the depth of the boosting trees actually did best with 3 instead of 1 for my data set compared to the diabetes one. </p>
# <p>2. Overall, both ensemble methods worked and created a better overall accuracy for the data compared to a single tree. This is due to the way in which these forests and boosting works. Having many different decision makers instead of one allows for a better decision since thing will need to come to an overall consensus. Only relying on one tree for a decision is much less accurate and can lead to worse decisions based on the training data. This showed true in both instances of the ensemble methods used in this notebook.</p>
